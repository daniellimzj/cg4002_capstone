# %%
import os
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

dws_data_path = "D:/CG4002/cg4002_capstone/hw_ai/mock_ml/A_DeviceMotion_data/dws_1/sub_1.csv"

dws_df = pd.read_csv(dws_data_path)

dws_df.plot(y= 'userAcceleration.x', color='red')
dws_df.plot(y= 'userAcceleration.y', color='green')
dws_df.plot(y= 'userAcceleration.z', color='blue')
dws_df.plot(y= 'attitude.roll', color='yellow')
dws_df.plot(y= 'attitude.pitch', color='black')
dws_df.plot(y= 'attitude.roll', color='purple')

plt.show()

# %%
jog_data_path = "D:/CG4002/cg4002_capstone/hw_ai/mock_ml/A_DeviceMotion_data/jog_9/sub_1.csv"
jog_df = pd.read_csv(jog_data_path)
jog_df.plot(y= 'userAcceleration.x', color='red')
jog_df.plot(y= 'userAcceleration.y', color='green')
jog_df.plot(y= 'userAcceleration.z', color='blue')
jog_df.plot(y= 'attitude.roll', color='yellow')
jog_df.plot(y= 'attitude.pitch', color='black')
jog_df.plot(y= 'attitude.roll', color='purple')

plt.show()

# %%
stand_data_path = "D:/CG4002/cg4002_capstone/hw_ai/mock_ml/A_DeviceMotion_data/std_6/sub_1.csv"
stand_df = pd.read_csv(stand_data_path)
stand_df.plot(y= 'userAcceleration.x', color='red')
stand_df.plot(y= 'userAcceleration.y', color='green')
stand_df.plot(y= 'userAcceleration.z', color='blue')
stand_df.plot(y= 'attitude.roll', color='yellow')
stand_df.plot(y= 'attitude.pitch', color='black')
stand_df.plot(y= 'attitude.roll', color='purple')

plt.show()

# %%
sit_data_path = "D:/CG4002/cg4002_capstone/hw_ai/mock_ml/A_DeviceMotion_data/sit_5/sub_1.csv"
sit_df = pd.read_csv(sit_data_path)
sit_df.plot(y= 'userAcceleration.x', color='red')
sit_df.plot(y= 'userAcceleration.y', color='green')
sit_df.plot(y= 'userAcceleration.z', color='blue')
sit_df.plot(y= 'attitude.roll', color='yellow')
sit_df.plot(y= 'attitude.pitch', color='black')
sit_df.plot(y= 'attitude.roll', color='purple')

plt.show()

# %%
walk_data_path = "D:/CG4002/cg4002_capstone/hw_ai/mock_ml/A_DeviceMotion_data/wlk_7/sub_1.csv"
walk_df = pd.read_csv(walk_data_path)
walk_df.plot(y= 'userAcceleration.x', color='red')
walk_df.plot(y= 'userAcceleration.y', color='green')
walk_df.plot(y= 'userAcceleration.z', color='blue')
walk_df.plot(y= 'attitude.roll', color='yellow')
walk_df.plot(y= 'attitude.pitch', color='black')
walk_df.plot(y= 'attitude.roll', color='purple')

plt.show()

# %%
ups_data_path = "D:/CG4002/cg4002_capstone/hw_ai/mock_ml/A_DeviceMotion_data/ups_3/sub_1.csv"
ups_df = pd.read_csv(ups_data_path)
ups_df.plot(y= 'userAcceleration.x', color='red')
ups_df.plot(y= 'userAcceleration.y', color='green')
ups_df.plot(y= 'userAcceleration.z', color='blue')
ups_df.plot(y= 'attitude.roll', color='yellow')
ups_df.plot(y= 'attitude.pitch', color='black')
ups_df.plot(y= 'attitude.roll', color='purple')

plt.show()

# %%
stand_df.plot(y= 'userAcceleration.x', color='yellow')
dws_df.plot(y= 'userAcceleration.x', color='red')
jog_df.plot(y= 'userAcceleration.x', color='blue')
sit_df.plot(y= 'userAcceleration.x', color='green')
ups_df.plot(y= 'userAcceleration.x', color='orange')
walk_df.plot(y= 'userAcceleration.x', color='black')
plt.show()

# %%
stand_df.plot(y= 'attitude.pitch', color='yellow')
sit_df.plot(y= 'attitude.pitch', color='green')
plt.show()
